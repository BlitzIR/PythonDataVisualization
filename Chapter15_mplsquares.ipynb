# %% [markdown]
# # Unit 1 - Matplotlib

# %% [markdown]
# ### type >jupyter in search bar to open new notebook

# %% [markdown]
# # Install matplotlib

# %% [markdown]
# # Plotting a Simple Line Graph

# %%
import matplotlib.pyplot as plt
squares = [1,4,9,16,25]
fig, ax = plt.subplots()
ax.plot(squares)
plt.show() #shows the graph

# %% [markdown]
# #   Label Type + Line Thickness

# %%
import matplotlib.pyplot as plt
squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()

#thickness of line
ax.plot(squares,linewidth=3)

#Set chart title and label axes
ax.set_title("Square Numbers", fontsize=24) #chart title
ax.set_xlabel("Value", fontsize=14) #x label (horiz)
ax.set_ylabel("Square of Value", fontsize=14) #y label (vert)

#Set size of tick labels/marks
ax.tick_params(labelsize=14)

ax.plot(squares)
plt.show() #shows the graph

# %% [markdown]
# # Correcting the Plot

# %%
import matplotlib.pyplot as plt

input_values = [1,2,3,4,5] #input values, so it starts at 1

squares = [1,4,9,16,25] 

fig, ax = plt.subplots()

ax.plot(input_values, squares, linewidth=3) #all values within the plot + linewidth

plt.show() #shows the graph

# %% [markdown]
# # Styling

# %%
import matplotlib.pyplot as plt
squares = [1,4,9,16,25]
fig, ax = plt.subplots()

plt.style.use("seaborn-v0_8")

ax.plot(squares)
plt.show() #shows the graph

# %% [markdown]
# # Scatterplot

# %% [markdown]
# ### basic plot

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.scatter(2,4)
plt.show()

# %% [markdown]
# # Calculating Data Automatically

# %% [markdown]
# # Defining Custom Colors

# %% [markdown]
# # Color Map

# %% [markdown]
# # Saving Your Plots Automatically

# %% [markdown]
# ## Styling the scatterplot

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8') #graph style
fig, ax = plt.subplots()

ax.scatter(2,4, s=200)

#title for plot
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

#tick label size
ax.tick_params(labelsize=14) 

plt.show()

# %% [markdown]
# # plot a series of points

# %%
import matplotlib.pyplot as plt

x_values = [1,2,3,4,5]
y_values = [1,4,9,16,25]


plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=100) #s=size
plt.show()

# %% [markdown]
# # Random Walks

# %% [markdown]
# ### #random_walk.py - makes random decisions about which direction the walk should take. The class needs three attributes: one variable to track the number of points in the walk, and two lists to store the x and y coords of each point in the walk.

# %%
#random_walk.py - makes random decisions about which direction the walk should take. The class needs three attributes: one variable to track the number of points in the walk, and two lists to store the x and y coords of each point in the walk.
from random import choice

class RandomWalk:
    """A class to generate random walks."""
    
    def __init__(self, num_points=5000):
        """Initialize attributes of walk"""
        self.num_points = num_points
        
        # All walks start @ (0,0)
        self.x_values= [0]
        self.y_values= [0]

# %% [markdown]
# ## Choosing Directions

# %%
#fill_walk <- determines full sequence points in the walk
def fill_walk(self):
    """Calculate all the points in the walk"""
    
    # Keep taking steps until the walk reacxhes the desired length.
    while len(self.x_values) < self.num_points:
        
        #decide which direction to go and how far to go.
        x_direction = choice([1,-1])
        x_distance = choice([0,1,2,3,4])
        x_step = x_direction * x_distance
        
        y_direction = choice([1,-1])
        y_distance = choice([0,1,2,3,4])
        y_step = y_direction * y_distance
        
        # Reject moves that go to nowhere
        if x_step == 0 and y_step == 0:
            continue
        
        #Calculate hte new position.
        x = self.x_values[-1] + x_step
        y = self.y_values[1] + y_step
        
        self.x_values.append(x)
        self.y_values.append(y)

# %% [markdown]
# ## plotting the random walk

# %%
import matplotlib.pyplot as plt

from random_walk import RandomWalk
#make a random walk
rw = RandomWalk()
rw.fill_walk()
#Plot the points in the walk
plt.style.use('classic')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 from random_walk import RandomWalk
#       4 #make a random walk
#       5 rw = RandomWalk()
#
# File c:\Users\xtrab\Desktop\Python\random_walk.py:2
#       1 from random import choice
# ----> 2 class RandomWalk:
#       3     """A class to generate random walks."""
#       4     def __init__(self, num_points=5000):
#
# File c:\Users\xtrab\Desktop\Python\random_walk.py:15, in RandomWalk()
#      12        """Calculate all the points in the walk."""
#      13 # Keep taking steps until the walk reaches the
# ---> 15    while len(self.x_values) < self.num_points:
#      16 # Decide which direction to go, and how far to
#      18        x_direction = choice([1, -1])
#      19        x_distance = choice([0, 1, 2, 3, 4])
#
# NameError: name 'self' is not defined

# %%
import matplotlib.pyplot as plt

from random_walk import RandomWalk

# Keep making new walks, as long as the program is active.
while True:
    # Make a random walk.
    rw = RandomWalk(50_000)
    rw.fill_walk()

    # Plot the points in the walk.
    plt.style.use('classic')
    fig, ax = plt.subplots()
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues,
       edgecolors='none', s=1)
    ax.set_aspect('equal')

    # Emphasize the first and last points.
    ax.scatter(0, 0, c='green', edgecolors='none', s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none',
        s=100)

    # Remove the axes.
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    plt.show()

    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 from random_walk import RandomWalk
#       5 # Keep making new walks, as long as the program is active.
#       6 while True:
#       7     # Make a random walk.
#
# File c:\Users\xtrab\Desktop\Python\random_walk.py:2
#       1 from random import choice
# ----> 2 class RandomWalk:
#       3     """A class to generate random walks."""
#       4     def __init__(self, num_points=5000):
#
# File c:\Users\xtrab\Desktop\Python\random_walk.py:15, in RandomWalk()
#      12        """Calculate all the points in the walk."""
#      13 # Keep taking steps until the walk reaches the
# ---> 15    while len(self.x_values) < self.num_points:
#      16 # Decide which direction to go, and how far to
#      18        x_direction = choice([1, -1])
# ...
